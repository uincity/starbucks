# %%
# 크롤링 모듈 임포트
from bs4 import BeautifulSoup 
from selenium import webdriver 

import time
import pandas as pd

# %%
# 스타벅스코리아 홈페이지 접속
driver = webdriver.Chrome('C:\\r_selenium\chromedriver')
url = 'https://www.starbucks.co.kr/store/store_map.do?disp=locale'
driver.get(url)

# %%
# 도시별 xpath값 저장
city_xpath = []
for i in range(17):
    text = f'//*[@id="container"]/div/form/fieldset/div/section/article[1]/article/article[2]/div[1]/div[2]/ul/li[{i+1}]/a'
    city_xpath.append(text)

# %%
#열려있는 페이지의 소스를 가져오기
html = driver.page_source
soup = BeautifulSoup(html,'html.parser')

# %%
# 도시별 이름 저장
city  = soup.select('ul.sido_arae_box')[0].text
city_name = []
leng = 2
for i in range(0,34,2):
    city_name_temp = city[i:leng]
    city_name.append(city_name_temp)
    leng+=2

# %%
#전체 버튼 정의
total_btn ='/html/body/div[4]/div[7]/div/form/fieldset/div/section/article[1]/article/article[2]/div[2]/div[3]/div/div/div[1]/ul/li[1]/a'

# %%
columns = ['매장명', '위도', '경도','매장타입','주소','전화번호']
startbucks_df_all = pd.DataFrame(columns = columns)  #strabuck전국매장 담을 df
st_cnt =1

for i in range(len(city_name)):

    time.sleep(3)
    # 해당 지역 클릭
    driver.find_element_by_xpath(city_xpath[i]).click()
    time.sleep(3)
    # 세종시 부분 처리를 위한 if문
    if(i<16):
        # 전체 버튼 클릭
        driver.find_element_by_xpath(total_btn).click()
        time.sleep(5)    
    # 스타벅스 서울시 매장 리스트 HTML 파싱
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')

    starbucks_soup_list = soup.select('li.quickResultLstCon')
    startbucks_list = []

    for item in starbucks_soup_list:
        name = item.select('strong')[0].text.strip() # 매장명
        lat = item['data-lat'].strip()
        long = item['data-long'].strip()
        # store_type = item.select('i')[0].text.strip() 
        store_type = item.select('i')[0].attrs.get('class')[0][4::]  #class이름 pin_다음이 매장의 type을 나타내는 아이콘임 
        adress = str(item.select('p')[0]).split('<br/>')[0].split('>')[1]
        tel = str(item.select('p')[0]).split('<br/>')[1].split('<')[0]
        startbucks_list.append([name,lat,long,store_type,adress,tel])
        st_cnt = st_cnt + 1 #매장총건수 카운트
    startbucks_df =pd.DataFrame(startbucks_list,columns=columns) #현재 지역 매장 담을 df
    # startbucks_df.to_excel(f'./startbucks_store_list_{i+1}_{city_name[i]}.xlsx', index = False)
    startbucks_df_all = startbucks_df_all.append(startbucks_df) #전국 df 결합 
    if(i<16):
        #지역 검색 클릭
        driver.find_element_by_xpath('//*[@id="container"]/div/form/fieldset/div/section/article[1]/article/header[2]/h3/a').click()

    print(f'{i+1}번째 {city_name[i]} 크롤링 종료')

print(f'크롤링을 종료합니다. 총매장수 : {st_cnt}')
startbucks_df_all.to_excel('./startbucks_store_list_20211031.xlsx', index = False)
# Out:
# 1번째 서울 크롤링 종료
# 2번째 경기 크롤링 종료
# 3번째 광주 크롤링 종료
# 4번째 대구 크롤링 종료
# 5번째 대전 크롤링 종료
# 6번째 부산 크롤링 종료
# 7번째 울산 크롤링 종료
# 8번째 인천 크롤링 종료
# 9번째 강원 크롤링 종료
# 10번째 경남 크롤링 종료
# 11번째 경북 크롤링 종료
# 12번째 전남 크롤링 종료
# 13번째 전북 크롤링 종료
# 14번째 충남 크롤링 종료
# 15번째 충북 크롤링 종료
# 16번째 제주 크롤링 종료
# 17번째 세종 크롤링 종료
# 크롤링을 종료합니다. 총매장수 : 1610

# %% [raw]
# #스타벅스 매장종류
# pin_general
# pin_generalDT
# pin_generalWT
# pin_reserve

# %%
startbucks_df_all
# Out:
#           매장명                 위도                  경도       매장타입  \
# 0     역삼아레나빌딩          37.501087          127.043069    general
# 1      논현역사거리          37.510178          127.022223    general
# 2     신사역성일빌딩          37.514132          127.020563    general
# 3      국기원사거리          37.499517          127.031495    general
# 4      스탈릿대치R          37.494668          127.062583    reserve
# 5        봉은사역          37.515000          127.063196    general
# 6     압구정윤성빌딩         37.5227934         127.0286009    general
# 7      코엑스별마당          37.510150          127.060275    general
# 8    삼성역섬유센터R          37.507750          127.060651    reserve
# 9        압구정R         37.5273669          127.033061    reserve
# 10       수서역R          37.488008          127.102650    reserve
# 11    양재강남빌딩R          37.485192          127.036685    reserve
# 12    선릉동신빌딩R          37.505321          127.050409    reserve
# 13    봉은사로선정릉          37.511293          127.048409    general
# 14      강남오거리          37.502117          127.026672    general
# 15  스타필드코엑스몰R           37.50999          127.061455    reserve
# 16     강남구청정문          37.518181          127.045995    general
# 17       도곡공원          37.492805          127.041309    general
# 18        강남R          37.497711          127.028439    reserve
# 19    대치은마사거리          37.498973          127.060172    general
# 20     청담영동대로          37.522156          127.056449    general
# 21        압구정          37.526283           127.02956    general
# 22      신사가로수          37.521933          127.022521    general
# 23      청담스타R          37.525216          127.041827    reserve
# 24       강남우성          37.492396          127.030910    general
# 25      학동사거리  37.52236449999999  127.03795430000002    general
# 26      대치사거리          37.503331          127.058817    general
# 27     포스코사거리         37.5075307  127.05742710000004    general
# 28    을지병원사거리         37.5191632         127.0286446    general
# 29        신사역         37.5162021         127.0207428    general
# ..        ...                ...                 ...        ...
# 4       제주서귀포  33.24779669999999         126.5621036    general
# 5       제주송악산          33.206799          126.290035    general
# 6       서귀포DT         33.2492775  126.50652289999993  generalDT
# 7       성산일출봉          33.462865          126.935544    general
# 8        제주중문          33.251128          126.412752    reserve
# 9      제주도남DT          33.480565          126.523646  generalDT
# 10       제주협재          33.393839          126.240490  generalWT
# 11     제주외도DT          33.492554          126.427169  generalDT
